# %%
# !pip install rasa
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.5/823.5 KB 11.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 77.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 83.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.5/238.5 KB 27.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 KB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 28.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 73.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.2/380.2 KB 38.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.0/498.0 MB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 96.4 MB/s eta 0:00:00
# ...

# %%
# !rasa init
# Out:
# /usr/local/lib/python3.8/dist-packages/rasa/core/tracker_store.py:876: MovedIn20Warning: Deprecated API features detected! These feature(s) are not compatible with SQLAlchemy 2.0. To prevent incompatible upgrades prior to updating applications, ensure requirements files are pinned to "sqlalchemy<2.0". Set environment variable SQLALCHEMY_WARN_20=1 to show all deprecation warnings.  Set environment variable SQLALCHEMY_SILENCE_UBER_WARNING=1 to silence this message. (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base: DeclarativeMeta = declarative_base()
# Welcome to Rasa! 🤖
#
# To get started quickly, an initial project will be created.
# If you need some help, check out the documentation at https://rasa.com/docs/rasa.
# Now let's start! 👇🏽
#
# t
# ory]WARNING: your terminal doesn't support cursor position requests (CPR).
# t
# t
# ory] chatbot
# ...

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# actions  config.yml	  data	      endpoints.yml  tests
# chatbot  credentials.yml  domain.yml  models

# %%
import os
os.chdir('/content/chat_bot')

# %%
# !pwd
# Out:
# /content/chat_bot

# %%
# !rasa train
# Out:
# /usr/local/lib/python3.8/dist-packages/rasa/core/tracker_store.py:876: MovedIn20Warning: Deprecated API features detected! These feature(s) are not compatible with SQLAlchemy 2.0. To prevent incompatible upgrades prior to updating applications, ensure requirements files are pinned to "sqlalchemy<2.0". Set environment variable SQLALCHEMY_WARN_20=1 to show all deprecation warnings.  Set environment variable SQLALCHEMY_SILENCE_UBER_WARNING=1 to silence this message. (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base: DeclarativeMeta = declarative_base()
# 2023-02-28 03:06:37 INFO     numexpr.utils  - NumExpr defaulting to 2 threads.
# 2023-02-28 03:06:38 INFO     root  - Generating grammar tables from /usr/lib/python3.8/lib2to3/Grammar.txt
# 2023-02-28 03:06:38 INFO     root  - Generating grammar tables from /usr/lib/python3.8/lib2to3/PatternGrammar.txt
# ...

# %%
# !rasa run actions
# Out:
# /usr/local/lib/python3.8/dist-packages/rasa/core/tracker_store.py:876: MovedIn20Warning: Deprecated API features detected! These feature(s) are not compatible with SQLAlchemy 2.0. To prevent incompatible upgrades prior to updating applications, ensure requirements files are pinned to "sqlalchemy<2.0". Set environment variable SQLALCHEMY_WARN_20=1 to show all deprecation warnings.  Set environment variable SQLALCHEMY_SILENCE_UBER_WARNING=1 to silence this message. (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base: DeclarativeMeta = declarative_base()
# 2023-02-27 15:35:20 INFO     rasa_sdk.endpoint  - Starting action endpoint server...
# 2023-02-27 15:35:20 INFO     rasa_sdk.endpoint  - Action endpoint is up and running on http://0.0.0.0:5055

# %%
# !rasa shell
# Out:
# /usr/local/lib/python3.8/dist-packages/rasa/core/tracker_store.py:876: MovedIn20Warning: Deprecated API features detected! These feature(s) are not compatible with SQLAlchemy 2.0. To prevent incompatible upgrades prior to updating applications, ensure requirements files are pinned to "sqlalchemy<2.0". Set environment variable SQLALCHEMY_WARN_20=1 to show all deprecation warnings.  Set environment variable SQLALCHEMY_SILENCE_UBER_WARNING=1 to silence this message. (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base: DeclarativeMeta = declarative_base()
# 2023-02-27 15:58:58 INFO     numexpr.utils  - NumExpr defaulting to 2 threads.
# 2023-02-27 15:58:59 INFO     root  - Generating grammar tables from /usr/lib/python3.8/lib2to3/Grammar.txt
# 2023-02-27 15:59:00 INFO     root  - Generating grammar tables from /usr/lib/python3.8/lib2to3/PatternGrammar.txt
# ...

# %%
# !zip -r /content/chatbot.zip /content/chatbot
# Out:
# updating: content/chatbot/ (stored 0%)
# updating: content/chatbot/domain.yml (deflated 45%)
# updating: content/chatbot/tests/ (stored 0%)
# updating: content/chatbot/tests/test_stories.yml (deflated 77%)
# updating: content/chatbot/.rasa/ (stored 0%)
# updating: content/chatbot/.rasa/cache/ (stored 0%)
# updating: content/chatbot/.rasa/cache/tmp_vrndpak/ (stored 0%)
# updating: content/chatbot/.rasa/cache/tmp_vrndpak/featurizer.json (deflated 30%)
# updating: content/chatbot/.rasa/cache/tmp_vrndpak/memorized_turns.json (deflated 47%)
# updating: content/chatbot/.rasa/cache/tmpajh4tyta/ (stored 0%)
# updating: content/chatbot/.rasa/cache/tmpajh4tyta/vocabularies.pkl (deflated 63%)
# updating: content/chatbot/.rasa/cache/tmpajh4tyta/oov_words.json (stored 0%)
# updating: content/chatbot/.rasa/cache/tmpukq06ztr/ (stored 0%)
# updating: content/chatbot/.rasa/cache/tmpukq06ztr/featurizer.json (deflated 57%)
# ...
